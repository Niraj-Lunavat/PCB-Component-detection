# %%
# !pip install ultralytics
import ultralytics
from IPython import display
from IPython.display import Image
display.clear_output()
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5016.7/8062.4 GB disk)

# %%
# !yolo detect predict model='/kaggle/input/weights/weights.pt' source='/kaggle/input/pcb-components-detection-dataset/Data/test/images' conf=0.5 save=True
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Model summary (fused): 268 layers, 68132235 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/111 /kaggle/input/pcb-components-detection-dataset/Data/test/images/VID20210601143927-96_jpg.rf.51037a593015ac38c8ac31613da3c066.jpg: 640x384 1 Cap1, 1 Cap2, 1 Cap3, 1 Cap4, 1 MOSFET, 1 Mov, 1 Resistor, 2 Transformers, 67.1ms
# image 2/111 /kaggle/input/pcb-components-detection-dataset/Data/test/images/VID20210601143927-96_jpg.rf.7ab5347b2d9efca349318d1c0f12a466.jpg: 640x384 1 Cap1, 1 Cap2, 1 Cap3, 1 Cap4, 1 MOSFET, 1 Mov, 1 Resistor, 2 Transformers, 26.4ms
# image 3/111 /kaggle/input/pcb-components-detection-dataset/Data/test/images/VID20210601143927-96_jpg.rf.f5f54e1ed4ec2434ed16cb072a95de94.jpg: 640x384 1 Cap1, 1 Cap2, 1 Cap3, 1 Cap4, 1 MOSFET, 1 Mov, 1 Resistor, 2 Transformers, 26.4ms
# ...

# %%
Image('/kaggle/working/runs/detect/predict/VID20210601143927-96_jpg.rf.f5f54e1ed4ec2434ed16cb072a95de94.jpg', width=500, height=400)
