# %%
# !pip install ultralytics
import ultralytics
from IPython import display
from IPython.display import Image
display.clear_output()
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5016.7/8062.4 GB disk)

# %%
# !yolo detect train model='yolov8x.pt' data='/kaggle/input/pcb-components-detection-dataset/Data/data.yaml' device='cuda' epochs=150 batch=8 imgsz=640 optimizer='Adam' dropout=0.1 conf=0.25 iou=0.5 source='/kaggle/input/pcb-components-detection-dataset/Data/train/images' nms=True lr0=0.0001 lrf=0.01 momentum=0.9 weight_decay=0.0003
# Out:
# ...
# 100%|████████████████████████████████████████| 131M/131M [00:02<00:00, 46.4MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
# !yolo detect predict model='/kaggle/working/runs/detect/train2/weights/best.pt' data='/kaggle/input/pcb-components-detection-dataset/Data/data.yaml' source='/kaggle/input/pcb-components-detection/Recording 2023-10-19 162503.mp4' conf=0.5 iou=0.7 save=True
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Model summary (fused): 268 layers, 68132235 parameters, 0 gradients, 257.4 GFLOPs
#
# video 1/1 (1/1167) /kaggle/input/pcb-components-detection/Recording 2023-10-19 162503.mp4: 352x640 2 Cap3s, 2 Cap4s, 1 MOSFET, 1 Mov, 65.1ms
# video 1/1 (2/1167) /kaggle/input/pcb-components-detection/Recording 2023-10-19 162503.mp4: 352x640 2 Cap3s, 2 Cap4s, 1 MOSFET, 1 Mov, 25.4ms
# video 1/1 (3/1167) /kaggle/input/pcb-components-detection/Recording 2023-10-19 162503.mp4: 352x640 1 Cap3, 2 Cap4s, 1 MOSFET, 1 Mov, 1 Transformer, 25.5ms
# video 1/1 (4/1167) /kaggle/input/pcb-components-detection/Recording 2023-10-19 162503.mp4: 352x640 3 Cap3s, 2 Cap4s, 1 MOSFET, 1 Mov, 1 Transformer, 25.4ms
# video 1/1 (5/1167) /kaggle/input/pcb-components-detection/Recording 2023-10-19 162503.mp4: 352x640 3 Cap3s, 2 Cap4s, 1 MOSFET, 1 Mov, 1 Transformer, 25.3ms
# ...
